# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
! cargo run --example prepare --features intel-mkl > prepare.csv
# Out:
#     Finished dev [unoptimized + debuginfo] target(s) in 0.43s
#      Running `target\debug\examples\prepare.exe`

# %%
df = pd.read_csv("prepare.csv", index_col="time")

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot(df["x"], df["y"], df["z"])
plt.savefig("prepare.png")
