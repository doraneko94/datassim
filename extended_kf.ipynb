# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# !cargo run --example state_generation --release --features intel-mkl
# Out:
#     Finished release [optimized] target(s) in 0.44s
#      Running `target\release\examples\state_generation.exe`

# %%
# !cargo run --example extended_kf --release --features intel-mkl -- 1.0
# Out:
#     Finished release [optimized] target(s) in 0.36s
#      Running `target\release\examples\extended_kf.exe 1.0`

# %%
df = pd.read_csv("L96_EKF_output_noinflation.txt", index_col=0, names=["Time(day)", "tracePa", "uf RMSE", "observation RMSE"])
df.plot()

# %%
# !cargo run --example extended_kf --release --features intel-mkl -- 1.1
# Out:
#     Finished release [optimized] target(s) in 0.37s
#      Running `target\release\examples\extended_kf.exe 1.1`

# %%
df = pd.read_csv("L96_EKF_output_noinflation.txt", index_col=0, names=["Time(day)", "tracePa", "uf RMSE", "observation RMSE"])
df.plot()
